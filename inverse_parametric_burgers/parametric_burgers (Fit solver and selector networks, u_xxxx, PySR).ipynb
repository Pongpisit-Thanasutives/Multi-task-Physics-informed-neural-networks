# %%
# %pylab inline
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import sys; sys.path.insert(0, "../"); from utils import *
from models import TanhProb
from parametric_discovery_pinnV2 import ParametricSolver

# Let's do facy optimizers
from optimizers import Lookahead, AdamGC, SGDGC
from madgrad import MADGRAD
from lbfgsnew import LBFGSNew

from pde_diff import TrainSTRidge, FiniteDiff, print_pde
from robust_pde_diff import print_pde, RobustPCA, Robust_LRSTR
from parametric_pde_diff import TrainSGTRidge, create_groups

from scipy.integrate import odeint
from numpy.fft import fft, ifft, fftfreq
from time import time

from pysr import pysr, best

fontsize = 20
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Running Python 3.9.8
# You can use npar for np.array

# %%
noise_intensity = 0.01; noisy_xt = False

# %%
data = pickle_load("../parametric_pde_data/parametric_burgers.pkl")

x = data['x']; spatial_dims = x.shape[0]
t = data['t']; time_dims = t.shape[0]

Exact = data['u']
X, T = np.meshgrid(x, t)

if noise_intensity > 0.0:
    print("Noisy Exact")
    Exact = perturb(Exact, intensity=noise_intensity, noise_type="normal")
else: print("Clean Exact")

X_star = np.hstack((to_column_vector(X), to_column_vector(T)))
u_star = to_column_vector(Exact.T)

# domain bounds
lb = X_star.min(axis=0)
ub = X_star.max(axis=0)

# Sampling training data points
N = 25000
training_idxs = sampling_from_rows(X_star, N, True)
X_train = X_star[training_idxs, :]
u_train = u_star[training_idxs, :]

if noise_intensity > 0.0 and noisy_xt:
    print("Noisy X_train")
    X_train = perturb(X_train, intensity=noise_intensity, noise_type="normal")
else: print("Clean X_train")

# to_tensor
X_star = to_tensor(X_star, True)
u_star = to_tensor(u_star, False)
X_train = to_tensor(X_train, True)
u_train = to_tensor(u_train, False)
lb = to_tensor(lb, False)
ub = to_tensor(ub, False)

u_xx_true = 0.1*np.ones(time_dims)
uu_x_true = -1*(1+0.25*np.sin(t))
# Out:
# Loaded from ../parametric_pde_data/parametric_burgers.pkl
# Noisy Exact
# Clean X_train

# %%
class AttentionSelectorNetwork(nn.Module):
    def __init__(self, layers, prob_activation=torch.sigmoid, bn=None, reg_intensity=1e-3):
        super(AttentionSelectorNetwork, self).__init__()
        # Nonlinear model, Training with PDE reg.
        assert len(layers) > 1
        self.linear1 = nn.Linear(layers[0], layers[0])
        self.prob_activation = prob_activation
        self.nonlinear_model = TorchMLP(dimensions=layers, activation_function=nn.Tanh, bn=bn, dropout=nn.Dropout(p=0.1))
        self.latest_weighted_features = None
        self.th = (1/layers[0])-(1e-10)
        self.reg_intensity = reg_intensity
        self.w = torch.tensor([1.0, 1.0, 1.0, 2.0, 3.0, 4.0])
        
    def xavier_init(self, m):
        if type(m) == nn.Linear:
            torch.nn.init.xavier_uniform_(m.weight)
            m.bias.data.fill_(0.01)
        
    def forward(self, inn, bi=False):
        if bi: att = binarize(self.weighted_features(inn), self.th)
        else: att = F.threshold(self.weighted_features(inn), self.th, 0.0)
        return self.nonlinear_model(inn*att)
    
    def weighted_features(self, inn):
        self.latest_weighted_features = self.prob_activation(self.linear1(inn)).mean(axis=0)
        return self.latest_weighted_features
    
    def loss(self, X_input, y_input):
        ut_approx = self.forward(X_input)
        mse_loss = F.mse_loss(ut_approx, y_input, reduction='mean')
        reg_term = F.relu(self.latest_weighted_features-self.th)
        
        l1 = mse_loss
        l2 = torch.norm(reg_term, p=0)+torch.dot(self.w, reg_term)
        
        return l1+self.reg_intensity*(l2)

class SemiSupModel(nn.Module):
    def __init__(self, network, selector, normalize_derivative_features=False, mini=None, maxi=None):
        super(SemiSupModel, self).__init__()
        self.network = network
        self.selector = selector
        self.normalize_derivative_features = normalize_derivative_features
        self.mini = mini
        self.maxi = maxi
        
    def forward(self, X_u_train):
        X_selector, y_selector = self.network.gradients_dict(*dimension_slicing(X_u_train))
        est = X_selector[:, 0:1]
        if self.normalize_derivative_features:
            X_selector = (X_selector-self.mini)/(self.maxi-self.mini)
        unsup_loss = self.selector.loss(X_selector, y_selector)
        return est, unsup_loss

# %%
### Version with normalized derivatives ###
# pretrained_state_dict = torch.load('../saved_path_inverse_burger/lbfgsnew_results/semisup_model_with_LayerNormDropout_without_physical_reg_trained250labeledsamples_trained0unlabeledsamples_2.2e-03.pth')
pretrained_state_dict = torch.load("./new_weights/pretrained_20000samples.pth")
network_state_dict = None
use_pretrained_weights = True

semisup_model = SemiSupModel(network=ParametricSolver(scale=False, lb=lb, ub=ub, input_feature='t', highest_order=4),
                            # Be careful of choosing the prob_activation to compute the attentional weights!
                            # selector=AttentionSelectorNetwork([5, 50, 50, 1], prob_activation=TanhProb(), bn=nn.LayerNorm),
                            selector=AttentionSelectorNetwork([5, 50, 50, 1], bn=nn.LayerNorm),
                            normalize_derivative_features=True,
                            mini=None,
                            maxi=None)

if use_pretrained_weights:
    print("Use pretrained weights")
    semisup_model.load_state_dict(pretrained_state_dict, strict=False)
    network_state_dict = semisup_model.network.state_dict()
    semisup_model.eval()
    referenced_derivatives, _ = semisup_model.network.gradients_dict(*dimension_slicing(X_star))
    semisup_model.mini = torch.min(referenced_derivatives, axis=0)[0].detach().requires_grad_(False)
    semisup_model.maxi = torch.max(referenced_derivatives, axis=0)[0].detach().requires_grad_(False)
    
semisup_model.selector = AttentionSelectorNetwork([6, 50, 50, 1], bn=nn.LayerNorm)
# Out:
# Using old implementation of TorchMLP. See models.py for more new model-related source code.
# Use pretrained weights
# Using old implementation of TorchMLP. See models.py for more new model-related source code.

# %%
F.mse_loss(semisup_model.network(*dimension_slicing(X_star)).detach(), u_star).item()
# Out:
# 4.250804522598628e-06

# %%
lets_pretrain = False

# %%
if lets_pretrain:
    print("Pretraining...")
    pretraining_optimizer = LBFGSNew(semisup_model.network.parameters(), 
                                     lr=1e-1, max_iter=300, 
                                     max_eval=int(300*1.25), history_size=150, 
                                     line_search_fn=True, batch_mode=False)

    semisup_model.train()
    for i in range(200):
        def pretraining_closure():
            global N, X_train, u_train
            if torch.is_grad_enabled(): pretraining_optimizer.zero_grad()
            # Only focusing on first [:N, :] elements
            mse_loss = F.mse_loss(semisup_model.network(*dimension_slicing(X_train))[:N, :], u_train[:N, :])
            if mse_loss.requires_grad: mse_loss.backward(retain_graph=False)
            return mse_loss

        pretraining_optimizer.step(pretraining_closure)

        l = pretraining_closure()
        if (i % 10) == 0:
            curr_loss = l.item()
            print("Epoch {}: ".format(i), curr_loss)
            
            # Sneak on the test performance...
            semisup_model.network.eval()
            test_performance = F.mse_loss(semisup_model.network(*dimension_slicing(X_star)).detach(), u_star).item()
            string_test_performance = scientific2string(test_performance)
            print('Test MSE:', string_test_performance)
    
    print("Computing derivatives features")
    semisup_model.eval()
    referenced_derivatives, _ = semisup_model.network.gradients_dict(*dimension_slicing(X_star))
    semisup_model.mini = torch.min(referenced_derivatives, axis=0)[0].detach().requires_grad_(False)
    semisup_model.maxi = torch.max(referenced_derivatives, axis=0)[0].detach().requires_grad_(False)

# %%
def pcgrad_closure(return_list=False):
    global N, X_train, u_train
    predictions, unsup_loss = semisup_model(X_train)
    losses = [F.mse_loss(predictions[:N, :], u_train[:N, :]), unsup_loss]
    updated_grads = []
    
    for i in range(2):
        optimizer.zero_grad()
        losses[i].backward(retain_graph=True)

        g_task = []
        for param in semisup_model.parameters():
            if param.grad is not None:
                g_task.append(Variable(param.grad.clone(), requires_grad=False))
            else:
                g_task.append(Variable(torch.zeros(param.shape), requires_grad=False))
        # appending the gradients from each task
        updated_grads.append(g_task)

    updated_grads = list(pcgrad.pc_grad_update(updated_grads))[0]
    for idx, param in enumerate(semisup_model.parameters()):
        param.grad = (updated_grads[0][idx]+updated_grads[1][idx])
        
    if not return_list: return losses[0]+losses[1]
    else: return losses

# %%
# Joint training | Do lambda comparison here
optimizer = MADGRAD([{'params':semisup_model.network.parameters()}, {'params':semisup_model.selector.parameters()}], lr=1e-6)
optimizer.param_groups[0]['lr'] = 1e-7
optimizer.param_groups[1]['lr'] = 1e-1

# %%
semisup_model = load_weights(semisup_model, "./new_weights/semisup_model_uxxxx_cleantx_noisy20000labels_unfinetuned.pth")
# Out:
# Loaded the model's weights properly

# %%
# Use ~idx to sample adversarial data points
# for i in range(250):
#     semisup_model.train()
#     optimizer.step(pcgrad_closure)
#     if i%25==0:
#         loss = pcgrad_closure(return_list=True); print(loss)
#         fi = semisup_model.selector.latest_weighted_features
#         print(fi); print(torch.argsort(fi))

# %%
# save(semisup_model, "./new_weights/semisup_model_uxxxx_cleantx_noisy20000labels_unfinetuned.pth")

# %%
# semisup_model = load_weights(semisup_model, "./new_weights/semisup_model_uxxxx_cleantx_noisy20000labels_unfinetuned.pth")

# %% [markdown]
# #### Fine-tuning the solver network

# %%
# Fine-tuning the solver network
f_opt = torch.optim.LBFGS(semisup_model.network.parameters(), lr=1e-1, max_iter=500, max_eval=int(1.25*500), history_size=500)

def finetuning_closure():
    global N, X_train, u_train
    if torch.is_grad_enabled(): f_opt.zero_grad()
    # the solver network only consider the first N samples.
    loss = F.mse_loss(semisup_model.network(*dimension_slicing(X_train[:N, :])), u_train[:N, :])
    if loss.requires_grad: loss.backward(retain_graph=True)
    return loss

semisup_model.network.train()
semisup_model.selector.eval()

for i in range(50):
    f_opt.step(finetuning_closure)
    if i%10==0:
        loss = finetuning_closure()
        print(loss.item())
# Out:
# 4.268495558790164e-06
# 4.264564267941751e-06
# 4.264211383997463e-06
# 4.264211383997463e-06
# 4.264211383997463e-06

# %%
referenced_derivatives, u_t = semisup_model.network.gradients_dict(*dimension_slicing(X_star))
referenced_derivatives = to_numpy(referenced_derivatives)
u_t = to_numpy(u_t)
feature_names = ['u', 'u_x', 'u_xx']

# %%
referenced_derivatives = np.delete(referenced_derivatives, -1, axis=1)
referenced_derivatives = np.delete(referenced_derivatives, -1, axis=1)
referenced_derivatives = np.delete(referenced_derivatives, 1, axis=1)

# %%
poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
Theta = poly.fit_transform(referenced_derivatives)

poly_feature_names = poly.get_feature_names(feature_names)
for i, f in enumerate(poly_feature_names):
    poly_feature_names[i] = f.replace(" ", "*")

# %%
Theta_grouped, Ut_grouped = create_groups(Theta, u_t, spatial_dims, time_dims)
# Out:
# The outputs can be used by the TrainSGTRidge function.

# %%
Xi,Tol,Losses = TrainSGTRidge(Theta_grouped, Ut_grouped)
xi = Xi[np.argmin(Losses)]
# Out:
# /Users/pongpisit/Desktop/Multi-task-Physics-informed-neural-networks/inverse_parametric_burgers/../parametric_pde_diff.py:609: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   candidate_norms[i] = Norm(np.vstack(A[:,i] for A in As), normalize)
# /Users/pongpisit/Desktop/Multi-task-Physics-informed-neural-networks/inverse_parametric_burgers/../parametric_pde_diff.py:579: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   W[biginds,i] = np.linalg.lstsq(Xs[i][:, biginds],ys[i])[0].reshape(len(biginds))

# %%
poly_feature_names
# Out:
# ['u', 'u_x', 'u_xx', 'u*u_x', 'u*u_xx', 'u_x*u_xx']

# %% [markdown]
# #### Plotting the results

# %%
pylab.rcParams['figure.figsize'] = (12, 8)
for j in range(xi.shape[0]): 
    if np.linalg.norm(xi[j,:]) > 10**-10:
        print(j, '->', poly_feature_names[j])
        plot(xi[j,:], label = poly_feature_names[j])

title('Burgers Equation Coefficients', fontsize = 16)
xlabel('Time', fontsize = 16)
ylabel('Coefficient Value', fontsize = 16)
legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize = 14)
# Out:
# 2 -> u_xx
# 3 -> u*u_x

# %%
# Considering only the u*u_x, u_xx features
referenced_derivatives[:, 1:2] = referenced_derivatives[:, 0:1]*referenced_derivatives[:, 1:2]
referenced_derivatives = np.delete(referenced_derivatives, 0, axis=1)

# Converting to tensors
referenced_derivatives = to_tensor(referenced_derivatives, False)
u_t = to_tensor(u_t, False)
t_star = X_star[:, 1:2].detach()

# %%
class CF(nn.Module):
    def __init__(self, n_hiddens=32):
        super(CF, self).__init__()
        self.cf1 = nn.Sequential(nn.Linear(1, n_hiddens), nn.Tanh(), 
                                 nn.Linear(n_hiddens, n_hiddens), nn.Tanh(), 
                                 nn.Linear(n_hiddens, 1))
        
        self.cf2 = nn.Sequential(nn.Linear(1, n_hiddens), nn.Tanh(), 
                                 nn.Linear(n_hiddens, n_hiddens), nn.Tanh(), 
                                 nn.Linear(n_hiddens, 1))
        
    def forward(self, e): return self.cf1(e), self.cf2(e)

# %%
cf_model = CF(32)

# %%
lbfgs_opt = torch.optim.LBFGS(cf_model.parameters(), 
                              lr=1e-1, max_iter=500, max_eval=int(1.25*500), history_size=500)

def cf_closure():
    global t_star, referenced_derivatives, u_t
    if torch.is_grad_enabled(): lbfgs_opt.zero_grad()
    pred_cf1, pred_cf2 = cf_model(t_star)
    cf_loss = F.mse_loss(pred_cf1*referenced_derivatives[:, 0:1]+pred_cf2*referenced_derivatives[:, 1:2], u_t)
    if cf_loss.requires_grad: cf_loss.backward(retain_graph=True)
    return cf_loss

# %%
for i in range(50):
    lbfgs_opt.step(cf_closure)
    if i%10==0: print(cf_closure().item())
# Out:
# 6.855193078081356e-06
# 6.8517560976033565e-06
# 6.851541911601089e-06
# 6.851541911601089e-06
# 6.851541911601089e-06

# %%
cf_model.eval()
pred_cf1, pred_cf2 = cf_model(to_tensor(t, False).reshape(-1, 1))
pred_cf1, pred_cf2 = to_numpy(pred_cf1), to_numpy(pred_cf2)

# %%
# Using PySR to discovry right away is not good (works sometimes, sometimes not!)
# if the derivatives are calculated using a neural network.
equations = pysr(
    t.reshape(-1, 1), pred_cf1,
    populations=50, npop=2000, niterations=5,
    binary_operators=["+", "*"],
    unary_operators=["sin"],
)
# Out:
# Running on julia -O3 --threads 4 /var/folders/z3/_stfms3523dd5mnfr3ch5n100000gp/T/tmpeiwwleos/runfile.jl
# Started!
#
# Cycles per second: 4.660e+03
# Head worker occupation: 4.9%
# Progress: 2 / 250 total iterations (0.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 4.940e+03
# Head worker occupation: 2.6%
# Progress: 4 / 250 total iterations (1.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 5.270e+03
# Head worker occupation: 1.9%
# Progress: 6 / 250 total iterations (2.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 4.730e+03
# Head worker occupation: 1.5%
# Progress: 7 / 250 total iterations (2.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 4.400e+03
# Head worker occupation: 1.2%
# Progress: 8 / 250 total iterations (3.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 4.190e+03
# Head worker occupation: 1.0%
# Progress: 9 / 250 total iterations (3.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 4.060e+03
# Head worker occupation: 0.9%
# Progress: 10 / 250 total iterations (4.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 3.910e+03
# Head worker occupation: 0.8%
# Progress: 11 / 250 total iterations (4.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 3.830e+03
# Head worker occupation: 0.7%
# Progress: 12 / 250 total iterations (4.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 4.040e+03
# Head worker occupation: 0.7%
# Progress: 14 / 250 total iterations (5.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 3.880e+03
# Head worker occupation: 0.6%
# Progress: 15 / 250 total iterations (6.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 3.660e+03
# Head worker occupation: 0.6%
# Progress: 16 / 250 total iterations (6.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 3.360e+03
# Head worker occupation: 0.5%
# Progress: 17 / 250 total iterations (6.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 3.630e+03
# Head worker occupation: 0.5%
# Progress: 19 / 250 total iterations (7.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 3.940e+03
# Head worker occupation: 0.5%
# Progress: 21 / 250 total iterations (8.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 4.240e+03
# Head worker occupation: 0.4%
# Progress: 23 / 250 total iterations (9.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 5.070e+03
# Head worker occupation: 0.4%
# Progress: 27 / 250 total iterations (10.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 5.430e+03
# Head worker occupation: 0.4%
# Progress: 29 / 250 total iterations (11.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 5.760e+03
# Head worker occupation: 0.4%
# Progress: 31 / 250 total iterations (12.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 5.810e+03
# Head worker occupation: 0.4%
# Progress: 33 / 250 total iterations (13.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 5.820e+03
# Head worker occupation: 0.4%
# Progress: 34 / 250 total iterations (13.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 6.690e+03
# Head worker occupation: 0.3%
# Progress: 38 / 250 total iterations (15.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 6.720e+03
# Head worker occupation: 0.3%
# Progress: 39 / 250 total iterations (15.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.320e+03
# Head worker occupation: 0.3%
# Progress: 43 / 250 total iterations (17.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.030e+03
# Head worker occupation: 0.3%
# Progress: 44 / 250 total iterations (17.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.080e+03
# Head worker occupation: 0.3%
# Progress: 46 / 250 total iterations (18.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.620e+03
# Head worker occupation: 0.3%
# Progress: 49 / 250 total iterations (19.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.990e+03
# Head worker occupation: 0.3%
# Progress: 51 / 250 total iterations (20.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.790e+03
# Head worker occupation: 0.3%
# Progress: 52 / 250 total iterations (20.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 8.250e+03
# Head worker occupation: 0.3%
# Progress: 54 / 250 total iterations (21.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 8.820e+03
# Head worker occupation: 0.3%
# Progress: 56 / 250 total iterations (22.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 8.580e+03
# Head worker occupation: 0.3%
# Progress: 58 / 250 total iterations (23.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 9.140e+03
# Head worker occupation: 0.3%
# Progress: 60 / 250 total iterations (24.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 9.280e+03
# Head worker occupation: 0.3%
# Progress: 63 / 250 total iterations (25.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 1.060e+04
# Head worker occupation: 0.3%
# Progress: 66 / 250 total iterations (26.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 1.050e+04
# Head worker occupation: 0.3%
# Progress: 67 / 250 total iterations (26.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 9.280e+03
# Head worker occupation: 0.3%
# Progress: 68 / 250 total iterations (27.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 9.530e+03
# Head worker occupation: 0.3%
# Progress: 70 / 250 total iterations (28.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 1.080e+04
# Head worker occupation: 0.3%
# Progress: 73 / 250 total iterations (29.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 1.100e+04
# Head worker occupation: 0.3%
# Progress: 75 / 250 total iterations (30.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# ...
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 1.050e+04
# Head worker occupation: 0.2%
# Progress: 209 / 250 total iterations (83.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 9.430e+03
# Head worker occupation: 0.2%
# Progress: 210 / 250 total iterations (84.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 8.900e+03
# Head worker occupation: 0.2%
# Progress: 213 / 250 total iterations (85.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 8.250e+03
# Head worker occupation: 0.2%
# Progress: 215 / 250 total iterations (86.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 8.510e+03
# Head worker occupation: 0.2%
# Progress: 218 / 250 total iterations (87.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 8.380e+03
# Head worker occupation: 0.2%
# Progress: 219 / 250 total iterations (87.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 8.140e+03
# Head worker occupation: 0.2%
# Progress: 222 / 250 total iterations (88.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.550e+03
# Head worker occupation: 0.2%
# Progress: 223 / 250 total iterations (89.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.610e+03
# Head worker occupation: 0.2%
# Progress: 226 / 250 total iterations (90.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.600e+03
# Head worker occupation: 0.2%
# Progress: 229 / 250 total iterations (91.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.010e+03
# Head worker occupation: 0.2%
# Progress: 233 / 250 total iterations (93.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.620e+03
# Head worker occupation: 0.2%
# Progress: 236 / 250 total iterations (94.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
#
# Cycles per second: 7.390e+03
# Head worker occupation: 0.2%
# Progress: 238 / 250 total iterations (95.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.405e-02  -0.000e+00  -1.0583714
# 5           2.385e-02  2.135e-03  (-1.0336956 + (-0.0049351854 * x0))
# 6           4.217e-03  1.733e+00  (-1.0198245 + (-0.2116583 * sin(x0)))
# 8           3.992e-03  2.742e-02  ((sin(x0 + -0.19103964) * -0.2143057) + -1.0040364)
# 9           3.737e-03  6.591e-02  (-1.0174847 + (-0.24472219 * sin(sin(-0.15327407 + x0))))
# 10          1.984e-03  6.333e-01  (-1.0118595 + (-0.21658123 * sin(0.3177617 + (0.9070392 * x0))))
# 11          1.975e-03  4.664e-03  (-1.0112226 + (-0.24646017 * sin(sin(0.30760142 + (0.90877956 * x0)))))
# 14          1.927e-03  8.124e-03  (-0.91114044 + (-0.33305246 * sin(sin(0.09594316 + ((0.08332382 * x0) + sin(x0))))))
# 15          1.732e-03  1.064e-01  (-1.0149832 + (-0.21871875 * sin(0.35960704 + ((-0.20668249 * sin(x0)) + (0.9020141 * x0)))))
# 16          1.691e-03  2.416e-02  (sin(sin(sin(x0 + ((x0 + (x0 * x0)) * -0.006568481))) * -0.25190237) + -1.0103133)
#
# ==============================
# Killing process... will return when done.

# %%
best(equations)
# Out:
# -0.2116583*sin(x0) - 1.0198245

# %%
### Noisless results ###
# Feature importance, noisless, 20000 samples
# [u, (t, x), u_x, u_xx, u_xxx, u_xxxx] use this one, −0.2202415sin(t)−1.0147734
# [0.3749, 0.5576, 0.2653, 0.4035, 0.1606, 0.1559]

# [u, t, u_x, u_xx, u_xxx] # −0.17302118sin(t)−1.0449685
# [0.2571, 0.4659, 0.3104, 0.6222, 0.1864]

# [t, x, u, u_x, u_xx, u_xxx]
# [0.3860, 0.3632, 0.3038, 0.5936, 0.3489, 0.1597]

### Clean (x, t) and noisy labels results ###
# Feature importance, 20000 samples, −0.21593435sin(t)−1.0181545
# [u, (t, x), u_x, u_xx, u_xxx, u_xxxx]
# [0.4065, 0.6292, 0.3592, 0.4562, 0.1581, 0.1578]

### Noisy (x, t) and noisy labels results ###
# Feature importance, 20000 samples, (-1.0178235 + (-0.21506631 * sin(t)))
# [u, (t, x), u_x, u_xx, u_xxx, u_xxxx]
# [0.2303, 0.3966, 0.5148, 0.2597, 0.1668, 0.1542]
